# %%
import pandas as pd
import numpy as np
from urllib.request import urlopen

pd.set_option('display.max_rows', 1000)
pd.set_option('display.max_columns', 1000)

# %%
df = pd.read_csv('salaries_1.csv')

# %%
df.head()
# Out:
#    work_year experience_level employment_type                  job_title  \
# 0       2022               MI              FT  Machine Learning Engineer
# 1       2022               MI              FT  Machine Learning Engineer
# 2       2022               MI              FT             Data Scientist
# 3       2022               MI              FT             Data Scientist
# 4       2022               MI              FT             Data Scientist
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0  130000             USD         130000                 US             0
# 1   90000             USD          90000                 US             0
# 2  120000             USD         120000                 US           100
# 3  100000             USD         100000                 US           100
# 4   85000             USD          85000                 US           100
#
#   company_location company_size
# 0               US            M
# ...

# %%
df.shape
# Out:
# (1332, 11)

# %%
df
# Out:
#       work_year experience_level employment_type                  job_title  \
# 0          2022               MI              FT  Machine Learning Engineer
# 1          2022               MI              FT  Machine Learning Engineer
# 2          2022               MI              FT             Data Scientist
# 3          2022               MI              FT             Data Scientist
# 4          2022               MI              FT             Data Scientist
# ...         ...              ...             ...                        ...
# 1327       2020               SE              FT             Data Scientist
# 1328       2021               MI              FT   Principal Data Scientist
# 1329       2020               EN              FT             Data Scientist
# 1330       2020               EN              CT      Business Data Analyst
# 1331       2021               SE              FT       Data Science Manager
#
# ...

# %% [markdown]
# There are 4 types of variables
#
# 1. Discrete
# 2. Nominal (You Cannot Compare) - Apple Oranage banana
# 3. Continuos
# 4. Ordinal (Comparing) - High Mediam Low

# %%
df_us = df[df['employee_residence'] == 'US']

# %%
for i in df_us['job_title'].unique():
    print(i)
# Out:
# Machine Learning Engineer
# Data Scientist
# Data Engineer
# Head of Data
# Data Analyst
# BI Analyst
# Research Engineer
# Data Operations Analyst
# ML Engineer
# Analytics Engineer
# Data Architect
# Data Operations Engineer
# 3D Computer Vision Researcher
# Data Science Lead
# Data Science Consultant
# Data Manager
# BI Data Analyst
# Machine Learning Manager
# Applied Scientist
# Lead Data Scientist
# Data Analytics Engineer
# ETL Developer
# AI Scientist
# Data Scientist Lead
# Data Science Manager
# Business Data Analyst
# Applied Machine Learning Scientist
# Machine Learning Scientist
# Financial Data Analyst
# Data Specialist
# Data Analytics Consultant
# Product Data Analyst
# Research Scientist
# Machine Learning Infrastructure Engineer
# Cloud Data Architect
# Machine Learning Developer
# Data Analytics Manager
# Head of Data Science
# NLP Engineer
# Applied Data Scientist
# Data Analytics Lead
# Data Engineering Manager
# Principal Data Scientist
# ...

# %%
df_us[df_us['job_title'] == 'Machine Learning Engineer']['salary'].mean()
# Out:
# 163614.4705882353

# %%
for i in df_us['job_title'].unique():
    print(i)
    print(df_us[df_us['job_title'] == i]['salary'].mean())
# Out:
# Machine Learning Engineer
# 163614.4705882353
# Data Scientist
# 151768.87044534413
# Data Engineer
# 150698.85407725323
# Head of Data
# 200000.0
# Data Analyst
# 112738.11188811189
# BI Analyst
# 76000.0
# Research Engineer
# 240000.0
# Data Operations Analyst
# 90562.5
# ML Engineer
# 166116.66666666666
# Analytics Engineer
# 151807.14285714287
# Data Architect
# 167164.37142857144
# Data Operations Engineer
# 81875.0
# 3D Computer Vision Researcher
# 5000.0
# Data Science Lead
# 165000.0
# Data Science Consultant
# 113500.0
# Data Manager
# 116000.0
# BI Data Analyst
# 77500.0
# Machine Learning Manager
# 175000.0
# Applied Scientist
# 172150.0
# Lead Data Scientist
# 173434.0
# Data Analytics Engineer
# 122500.0
# ETL Developer
# 151183.75
# AI Scientist
# 142500.0
# Data Scientist Lead
# 183000.0
# Data Science Manager
# 190459.34615384616
# Business Data Analyst
# 121250.0
# Applied Machine Learning Scientist
# 234666.66666666666
# Machine Learning Scientist
# ...

# %%
df_us.head()
# Out:
#    work_year experience_level employment_type                  job_title  \
# 0       2022               MI              FT  Machine Learning Engineer
# 1       2022               MI              FT  Machine Learning Engineer
# 2       2022               MI              FT             Data Scientist
# 3       2022               MI              FT             Data Scientist
# 4       2022               MI              FT             Data Scientist
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0  130000             USD         130000                 US             0
# 1   90000             USD          90000                 US             0
# 2  120000             USD         120000                 US           100
# 3  100000             USD         100000                 US           100
# 4   85000             USD          85000                 US           100
#
#   company_location company_size
# 0               US            M
# ...

# %%
df_us.pivot_table(values = 'salary', index=['experience_level','job_title'], aggfunc= np.mean)
# Out:
#                                                                   salary
# experience_level job_title
# EN               AI Scientist                               50000.000000
#                  Analytics Engineer                        130000.000000
#                  BI Analyst                                 76000.000000
#                  BI Data Analyst                            56000.000000
#                  Big Data Engineer                          70000.000000
#                  Business Data Analyst                     100000.000000
#                  Computer Vision Engineer                  125000.000000
#                  Computer Vision Software Engineer          70000.000000
#                  Data Analyst                               75800.000000
#                  Data Engineer                              90357.142857
#                  Data Science Consultant                    90000.000000
# ...

# %%
df
# Out:
#       work_year experience_level employment_type                  job_title  \
# 0          2022               MI              FT  Machine Learning Engineer
# 1          2022               MI              FT  Machine Learning Engineer
# 2          2022               MI              FT             Data Scientist
# 3          2022               MI              FT             Data Scientist
# 4          2022               MI              FT             Data Scientist
# ...         ...              ...             ...                        ...
# 1327       2020               SE              FT             Data Scientist
# 1328       2021               MI              FT   Principal Data Scientist
# 1329       2020               EN              FT             Data Scientist
# 1330       2020               EN              CT      Business Data Analyst
# 1331       2021               SE              FT       Data Science Manager
#
# ...

# %%
df.employee_residence.unique()
# Out:
# array(['US', 'ES', 'GB', 'FR', 'CA', 'CN', 'MX', 'BR', 'IN', 'AU', 'PT',
#        'DE', 'NG', 'CZ', 'CR', 'TR', 'CL', 'PR', 'FI', 'TH', 'NL', 'GR',
#        'DK', 'BO', 'PH', 'AX', 'DO', 'AR', 'BE', 'AT', 'SG', 'EG', 'ID',
#        'IT', 'AE', 'IE', 'SI', 'MY', 'JP', 'EE', 'PK', 'PL', 'HN', 'TN',
#        'CH', 'RU', 'DZ', 'VN', 'IQ', 'UA', 'BG', 'HU', 'JE', 'RS', 'KE',
#        'CO', 'NZ', 'IR', 'RO', 'HK', 'MD', 'LU', 'HR', 'MT'], dtype=object)

# %%
df.work_year.unique()
# Out:
# array([2022, 2021, 2020])

# %%
df.pivot_table(values = 'salary_in_usd', index=['job_title','employee_residence'], aggfunc= (np.mean, np.min))
# Out:
#                                                                amin  \
# job_title                                employee_residence
# 3D Computer Vision Researcher            AX                    2324
#                                          IN                    5409
#                                          US                    5000
# AI Scientist                             BR                   12000
#                                          DK                   45896
#                                          ES                   55000
#                                          IN                    3078
#                                          PK                   12000
#                                          PT                   31586
#                                          US                   50000
# Analytics Engineer                       AR                   48000
#                                          BO                    7500
# ...

# %%
Countries_avg_salary = df.pivot_table(values = 'salary_in_usd', index= 'employee_residence', aggfunc= np.mean)

# %%
Countries_avg_salary.sort_values(by=['salary_in_usd'], ascending=False)
# Out:
#                     salary_in_usd
# employee_residence
# MY                  200000.000000
# PR                  166000.000000
# US                  149035.460440
# NZ                  125000.000000
# CH                  120221.000000
# DO                  110000.000000
# CA                  106414.894737
# RU                  105750.000000
# JP                  103537.714286
# AE                  100000.000000
# JE                  100000.000000
# DZ                  100000.000000
# IQ                  100000.000000
# SG                   91171.333333
# NG                   86666.666667
# CN                   84367.500000
# AU                   83675.333333
# DE                   83539.806452
# GB                   82707.120482
# BG                   80000.000000
# BE                   76936.000000
# CL                   72519.000000
# NL                   72013.400000
# AT                   69371.500000
# IE                   68436.000000
# HK                   66022.000000
# ...

# %%
df.head()
# Out:
#    work_year experience_level employment_type                  job_title  \
# 0       2022               MI              FT  Machine Learning Engineer
# 1       2022               MI              FT  Machine Learning Engineer
# 2       2022               MI              FT             Data Scientist
# 3       2022               MI              FT             Data Scientist
# 4       2022               MI              FT             Data Scientist
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0  130000             USD         130000                 US             0
# 1   90000             USD          90000                 US             0
# 2  120000             USD         120000                 US           100
# 3  100000             USD         100000                 US           100
# 4   85000             USD          85000                 US           100
#
#   company_location company_size
# 0               US            M
# ...

# %%
df.pivot_table(values = 'salary_in_usd', index= ['job_title','experience_level'], aggfunc= np.mean)
# Out:
#                                                            salary_in_usd
# job_title                                experience_level
# 3D Computer Vision Researcher            EN                  2324.000000
#                                          MI                  5409.000000
#                                          SE                  5000.000000
# AI Scientist                             EN                 24659.000000
#                                          EX                200000.000000
#                                          MI                173333.333333
#                                          SE                 55000.000000
# Analytics Engineer                       EN                130000.000000
#                                          EX                171166.666667
#                                          MI                 82928.571429
#                                          SE                142688.068966
# ...

# %%
df
# Out:
#       work_year experience_level employment_type                  job_title  \
# 0          2022               MI              FT  Machine Learning Engineer
# 1          2022               MI              FT  Machine Learning Engineer
# 2          2022               MI              FT             Data Scientist
# 3          2022               MI              FT             Data Scientist
# 4          2022               MI              FT             Data Scientist
# ...         ...              ...             ...                        ...
# 1327       2020               SE              FT             Data Scientist
# 1328       2021               MI              FT   Principal Data Scientist
# 1329       2020               EN              FT             Data Scientist
# 1330       2020               EN              CT      Business Data Analyst
# 1331       2021               SE              FT       Data Science Manager
#
# ...

# %%
df[df['salary_currency']== 'INR'].pivot_table(values='salary_in_usd', index= 'job_title', aggfunc=np.mean)
# Out:
#                                     salary_in_usd
# job_title
# 3D Computer Vision Researcher         5409.000000
# AI Scientist                         10565.500000
# Applied Machine Learning Scientist   30787.000000
# BI Data Analyst                       8120.000000
# Big Data Engineer                    14907.000000
# Business Data Analyst                17959.000000
# Data Analyst                          6085.666667
# Data Engineer                        19762.750000
# Data Science Consultant               5707.000000
# Data Science Manager                 74379.500000
# Data Scientist                       26381.909091
# Head of Machine Learning             76967.000000
# Lead Data Analyst                    19609.000000
# Lead Data Scientist                  40570.000000
# Lead Machine Learning Engineer       96209.000000
# Machine Learning Engineer            45303.500000
# Machine Learning Research Engineer   12171.000000
# Power BI Developer                    5409.000000
# ...

# %% [markdown]
# univariate data - One Variable
# bivariate data -  Two Variable
# multivariate data - More than Two Variable

# %%
df.head()
# Out:
#    work_year experience_level employment_type                  job_title  \
# 0       2022               MI              FT  Machine Learning Engineer
# 1       2022               MI              FT  Machine Learning Engineer
# 2       2022               MI              FT             Data Scientist
# 3       2022               MI              FT             Data Scientist
# 4       2022               MI              FT             Data Scientist
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0  130000             USD         130000                 US             0
# 1   90000             USD          90000                 US             0
# 2  120000             USD         120000                 US           100
# 3  100000             USD         100000                 US           100
# 4   85000             USD          85000                 US           100
#
#   company_location company_size
# 0               US            M
# ...

# %%
df.work_year.value_counts(dropna=False)
# Out:
# 2022    1029
# 2021     228
# 2020      75
# Name: work_year, dtype: int64

# %%
for i in df:
# Out:
# work_year
# experience_level
# employment_type
# job_title
# salary
# salary_currency
# salary_in_usd
# employee_residence
# remote_ratio
# company_location
# company_size

# %%
df.columns
# Out:
# Index(['work_year', 'experience_level', 'employment_type', 'job_title',
#        'salary', 'salary_currency', 'salary_in_usd', 'employee_residence',
#        'remote_ratio', 'company_location', 'company_size'],
#       dtype='object')

# %%
# for i in df.columns:
#     print(df[i].value_counts())

# %%
df.describe()
# Out:
#          work_year        salary  salary_in_usd  remote_ratio
# count  1332.000000  1.332000e+03    1332.000000   1332.000000
# mean   2021.716216  2.377124e+05  123374.658408     63.851351
# std       0.562228  1.077369e+06   65945.872172     45.263587
# min    2020.000000  2.324000e+03    2324.000000      0.000000
# 25%    2022.000000  8.000000e+04   75593.000000      0.000000
# 50%    2022.000000  1.300000e+05  120000.000000    100.000000
# 75%    2022.000000  1.751000e+05  164997.000000    100.000000
# max    2022.000000  3.040000e+07  600000.000000    100.000000

# %%
np.mean(df.salary)
# Out:
# 237712.38438438438
